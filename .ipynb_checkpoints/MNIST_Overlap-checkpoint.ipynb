# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
from torchvision import transforms
from torch.utils.data import DataLoader
from tqdm.notebook import tqdm
from OverlapIndex import OverlapIndex
import numpy as np
from sklearn.model_selection import StratifiedShuffleSplit

# ── 1) DEVICE SELECTION ───────────────────────────────────────────
if torch.cuda.is_available():
    device = torch.device("cuda")
elif torch.backends.mps.is_available():
    device = torch.device("mps")
else:
    device = torch.device("cpu")
print("Using device:", device)

# ── 2) SEED ───────────────────────────────────────────────────────
torch.manual_seed(0)
np.random.seed(0)

# ── 3) DATASETS & DATALOADERS ────────────────────────────────────
transform = transforms.ToTensor()
train_ds = torchvision.datasets.MNIST("./data", train=True,  download=True, transform=transform)
val_ds   = torchvision.datasets.MNIST("./data", train=False, download=True, transform=transform)

train_loader = DataLoader(train_ds, batch_size=64, shuffle=True,
                          num_workers=4, pin_memory=True)
val_loader   = DataLoader(val_ds,   batch_size=1024, shuffle=False,
                          num_workers=4, pin_memory=True)

# ── 4) LOAD FULL VALIDATION SET ONCE ─────────────────────────────
val_inputs = []
val_labels = []
for xb, yb in val_loader:
    val_inputs.append(xb)
    val_labels.append(yb)
val_inputs = torch.cat(val_inputs, dim=0).to(torch.float32).to(device)  # (10000,1,28,28)
val_labels = torch.cat(val_labels, dim=0).to(torch.long).to(device)     # (10000,)

# ── 5) STRATIFIED SUBSAMPLE FOR OI ───────────────────────────────
y_np = val_labels.cpu().numpy()
sss = StratifiedShuffleSplit(n_splits=1, train_size=1000, random_state=0)
sub_idx, _ = next(sss.split(np.zeros_like(y_np), y_np))
sub_inputs  = val_inputs[sub_idx]
sub_labels  = val_labels[sub_idx]
y_sub_np    = sub_labels.cpu().numpy()  # for OverlapIndex

# ── 6) MODEL DEFINITION ───────────────────────────────────────────
class CNN(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(1,16,5,padding=2)
        self.pool1 = nn.MaxPool2d(2,2)
        self.conv2 = nn.Conv2d(16,32,5,padding=2)
        self.pool2 = nn.MaxPool2d(2,2)
        self.fc1   = nn.Linear(32*7*7,128)
        self.fc2   = nn.Linear(128,10)

    def forward(self, x):
        x = F.relu(self.conv1(x))
        z1 = self.pool1(x)           # conv1_pooled
        x = F.relu(self.conv2(z1))
        z2 = self.pool2(x)           # conv2_pooled

        flat = z2.view(z2.size(0), -1)
        z3   = F.relu(self.fc1(flat))  # fc1
        out  = self.fc2(z3)
        return out, z1, z2, z3

model = CNN().to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
criterion = nn.CrossEntropyLoss()

# ── 7) STORAGE ────────────────────────────────────────────────────
oi_conv1 = []
oi_conv2 = []
oi_fc1   = []
val_accuracy_history = []

# ── 8) TRAINING LOOP ─────────────────────────────────────────────
model.train()
for epoch in range(1):  # adjust epochs if needed
    loop = tqdm(enumerate(train_loader), total=len(train_loader))
    for batch_idx, (x_batch, y_batch) in loop:
        x_batch, y_batch = x_batch.to(device), y_batch.to(device)

        # --- training step ---
        optimizer.zero_grad()
        logits, _, _, _ = model(x_batch)
        loss = criterion(logits, y_batch)
        loss.backward()
        optimizer.step()

        # --- validation accuracy (every batch) ---
        model.eval()
        with torch.no_grad():
            logits_val, _, _, _ = model(val_inputs)
            preds = logits_val.argmax(dim=1)
            val_acc = (preds == val_labels).float().mean().item()
            val_accuracy_history.append(val_acc)

            # --- only every 5 batches: compute OI on subsample ---
            if batch_idx % 5 == 0:
                _, z1_sub, z2_sub, z3_sub = model(sub_inputs)
                X1 = z1_sub.view(z1_sub.size(0), -1).cpu().numpy()
                X2 = z2_sub.view(z2_sub.size(0), -1).cpu().numpy()
                X3 = z3_sub.view(z3_sub.size(0), -1).cpu().numpy()
                rho=0.9
                oi1 = OverlapIndex(rho=rho, ART="Fuzzy")
                oi2 = OverlapIndex(rho=rho, ART="Fuzzy")
                oi3 = OverlapIndex(rho=rho, ART="Fuzzy")

                # prepare once per OI instance
                X1_p = oi1.ARTMAP.prepare_data(X1)
                X2_p = oi2.ARTMAP.prepare_data(X2)
                X3_p = oi3.ARTMAP.prepare_data(X3)

                oi_conv1.append(oi1.add_batch(X1_p, y_sub_np))
                oi_conv2.append(oi2.add_batch(X2_p, y_sub_np))
                oi_fc1.append(  oi3.add_batch(X3_p, y_sub_np))

        model.train()
        loop.set_postfix(loss=loss.item(), val_acc=val_acc)
        
# ── 9) RAW VALIDATION OI ──────────────────────────────────────────
X_raw = sub_inputs.view(sub_inputs.size(0), -1).cpu().numpy()
oi_raw = OverlapIndex(rho=0.9, ART="Fuzzy")
X_prep = oi_raw.ARTMAP.prepare_data(X_raw)
oi_val_raw = oi_raw.add_batch(X_prep, y_sub_np)

print("Done.")
print(f"Total batches:        {len(train_loader)}")
print(f"OI computed batches:  {len(oi_conv1)}  (≈ every 5th batch)")
print(f"Raw-val OI:           {oi_val_raw:.4f}")
# Out:
# Using device: mps
# /Users/niklasmelton/Library/Python/3.9/lib/python/site-packages/torch/utils/data/dataloader.py:683: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# /Users/niklasmelton/Library/Python/3.9/lib/python/site-packages/torch/utils/data/dataloader.py:683: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
#   0%|          | 0/938 [00:00<?, ?it/s]
# Done.
# Total batches:        938
# OI computed batches:  188  (≈ every 5th batch)
# Raw-val OI:           0.8511

# %%
# ── 9) RAW VALIDATION OI ──────────────────────────────────────────
X_raw = sub_inputs.view(sub_inputs.size(0), -1).cpu().numpy()
oi_raw = OverlapIndex(rho=0.9, ART="Fuzzy")
X_prep = oi_raw.ARTMAP.prepare_data(X_raw)
oi_val_raw = oi_raw.add_batch(X_prep, y_sub_np)

print("Done.")
print(f"Total batches:        {len(train_loader)}")
print(f"OI computed batches:  {len(oi_conv1)}  (≈ every 5th batch)")
print(f"Raw-val OI:           {oi_val_raw:.4f}")
# Out:
# Done.
# Total batches:        938
# OI computed batches:  188  (≈ every 5th batch)
# Raw-val OI:           0.7557

# %%
import pickle
pickle.dump(
    {"conv1_pooled": oi_conv1, "conv2_pooled":oi_conv2, "fc1":oi_fc1, "raw": oi_val_raw, "val_accuracy_history":val_accuracy_history}, 
    open("mnist_oi.pickle", "wb")
)

# %%
import matplotlib.pyplot as plt
import numpy as np
import pickle
data = pickle.load(open("mnist_oi.pickle", "rb"))

oi_conv1 = data["conv1_pooled"]
oi_conv2 = data["conv2_pooled"]
oi_fc1 = data["fc1"]
oi_val_raw = data["raw"]
val_accuracy_history = data["val_accuracy_history"]

# x‐axis for OI (every 5 batches)
batches_oi = 5 * np.arange(len(oi_conv1))
# x‐axis for accuracy (every batch)
batches_acc = np.arange(len(val_accuracy_history))

fig, ax1 = plt.subplots(figsize=(8, 5))

# Plot Overlap Index curves on left y-axis
ax1.plot(batches_oi, oi_conv1, label='conv1_pooled')
ax1.plot(batches_oi, oi_conv2, label='conv2_pooled')
ax1.plot(batches_oi, oi_fc1,   label='fc1')
ax1.hlines(oi_val_raw, xmin=batches_oi[0], xmax=batches_oi[-1],
           label='raw data', linestyles='dashed')
ax1.set_xlabel('Batch Index')
ax1.set_ylabel('Overlap Index')
ax1.legend(loc='lower right', title='Overlap Indices')

# Create a second y-axis for accuracy
ax2 = ax1.twinx()
ax2.plot(batches_acc, val_accuracy_history, color='gray', alpha=0.6, label='val accuracy')
ax2.set_ylabel('Validation Accuracy')
ax2.legend(loc='upper left')

plt.title('Overlap Index for MNIST at Each Feature Level')
plt.tight_layout()
plt.savefig("figures/mnist_oi_accuracy.png")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 14
#      12 batches_oi = 5 * np.arange(len(oi_conv1))
#      13 # x‐axis for accuracy (every batch)
# ---> 14 batches_acc = np.arange(len(val_accuracy_history))
#      16 fig, ax1 = plt.subplots(figsize=(8, 5))
#      18 # Plot Overlap Index curves on left y-axis
#
# NameError: name 'val_accuracy_history' is not defined

# %%
import matplotlib.pyplot as plt
import networkx as nx

# Define the CNN architecture graph
layers = [
    "Input\n1×28×28",
    "Conv1\n16 @ 5×5",
    "Pool1\n2×2 max",
    "Conv2\n32 @ 5×5",
    "Pool2\n2×2 max",
    "FC1\n128 units",
    "FC2\n10 units"
]

G = nx.DiGraph()
for i in range(len(layers) - 1):
    G.add_edge(layers[i], layers[i+1])

# Position nodes vertically
pos = {layer: (0, -i) for i, layer in enumerate(layers)}

# Plot vertically
fig, ax = plt.subplots(figsize=(2, 8))
nx.draw(
    G,
    pos,
    with_labels=True,
    node_shape='s',
    node_size=3000,
    font_size=10,
    arrowsize=20,
    ax=ax
)
plt.title("CNN Architecture\nfor MNIST")
plt.axis('off')
plt.tight_layout(pad=0)
fig.savefig(
    "figures/cnn_arch.png",
    bbox_inches="tight",
    pad_inches=0
)
plt.show()
